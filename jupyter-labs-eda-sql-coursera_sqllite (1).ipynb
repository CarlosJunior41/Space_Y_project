# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.4.1
# Out:
# ...
#   Using cached sqlalchemy-1.4.1-cp313-cp313-win_amd64.whl
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.48
#     Uninstalling SQLAlchemy-2.0.48:
#       Successfully uninstalled SQLAlchemy-2.0.48
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.1 which is incompatible.

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# ...
#   Using cached sqlalchemy-2.0.48-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# ...
# Using cached sqlalchemy-2.0.48-cp313-cp313-win_amd64.whl (2.1 MB)
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.1
#     Uninstalling SQLAlchemy-1.4.1:
#       Successfully uninstalled SQLAlchemy-1.4.1
# ...

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome      Landing_Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %%sql
# SELECT Launch_Site, COUNT(*) AS Count FROM SPACEXTABLE GROUP BY Launch_Site ORDER BY COUNT(*) DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS SLC-40', 34),
#  ('CCAFS LC-40', 26),
#  ('KSC LC-39A', 25),
#  ('VAFB SLC-4E', 16)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %%sql
# SELECT * FROM SPACEXTABLE WHERE Launch_site LIKE 'CCA%' LIMIT 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04', '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  ('2010-12-08', '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  ('2012-05-22', '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  ('2012-10-08', '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  ('2013-03-01', '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %%sql
# SELECT SUM(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Customer = 'NASA (CRS)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(45596,)]

# %% [raw]
# #####  Display the unique customers

# %%
# %%sql
# SELECT COUNT(distinct Customer) AS qtd
# FROM SPACEXTABLE
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(53,)]

# %% [markdown]
# #####  Display the launchs for other Customers

# %%
# %%sql
# SELECT Customer, COUNT(*) AS qtd
# FROM SPACEXTABLE
# WHERE Customer NOT LIKE '%NASA%' AND Customer NOT LIKE '%SpaceX%'
# GROUP BY Customer
# ORDER BY qtd DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Iridium Communications', 7),
#  ('SES', 5),
#  ('Thaicom', 2),
#  ('Telesat', 2),
#  ('SKY Perfect JSAT Group', 2),
#  ('Orbcomm', 2),
#  ('AsiaSat', 2),
#  ('ABS Eutelsat', 2),
#  ('USSF', 1),
#  ('USAF', 1),
#  ('U.S. Space Force', 1),
#  ('U.S. Air Force', 1),
#  ('Turkmenistan National Space Agency', 1),
#  ('Thales-Alenia/BTRC', 1),
#  ('Telkom Indonesia', 1),
#  ('Spaceflight Industries', 1),
#  ('Spacecom', 1),
#  ('Sky Perfect JSAT, Kacific 1', 1),
#  ('SES EchoStar', 1),
#  ('Republic of Korea Army, Spaceflight Industries (BlackSky)', 1),
#  ('PSN, SpaceIL / IAI', 1),
#  ('Northrop Grumman', 1),
#  ('NSPO', 1),
#  ('NRO', 1),
#  ('MDA', 1),
#  ('KT Corporation', 1),
#  ('Intelsat', 1),
#  ('Inmarsat', 1),
#  ('Hispasat  NovaWurks', 1),
#  ('Es hailSat', 1),
#  ('EchoStar', 1),
#  ('Canadian Space Agency (CSA)', 1),
#  ('CONAE', 1),
#  ('Bulsatcom', 1)]

# %%
# %%sql
# SELECT SUM(PAYLOAD_MASS__KG_)
# FROM SPACEXTABLE
# WHERE Customer LIKE '%NASA%' OR Customer LIKE '%SpaceX%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(358892,)]

# %%
# %%sql
# SELECT SUM(PAYLOAD_MASS__KG_)
# FROM SPACEXTABLE
# WHERE Customer NOT LIKE '%NASA%' AND Customer NOT LIKE '%SpaceX%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(261075,)]

# %%
# %%sql
# SELECT Customer, COUNT(*) AS qtd
# FROM SPACEXTABLE
# WHERE Customer LIKE '%NASA%' OR Customer LIKE '%SpaceX%'
# GROUP BY Customer
# ORDER BY qtd DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('NASA (CRS)', 20),
#  ('SpaceX', 13),
#  ('SpaceX, Planet Labs', 2),
#  ('U.S. Air Force NASA NOAA', 1),
#  ('SpaceX, Spaceflight Industries (BlackSky), Planet Labs', 1),
#  ('SpaceX, Planet Labs, PlanetIQ', 1),
#  ('NASA / NOAA / ESA / EUMETSAT', 1),
#  ('NASA (LSP) NOAA CNES', 1),
#  ('NASA (LSP)', 1),
#  ('NASA (CTS)', 1),
#  ('NASA (CRS), Kacific 1', 1),
#  ('NASA (COTS) NRO', 1),
#  ('NASA (COTS)', 1),
#  ('NASA (CCP)', 1),
#  ('NASA (CCDev)', 1),
#  ('NASA (CCD) ', 1),
#  ('Iridium Communications GFZ ‚ NASA', 1),
#  ('Hisdesat exactEarth SpaceX', 1),
#  ('CONAE, PlanetIQ, SpaceX', 1)]

# %%
# %%sql
# SELECT Customer, COUNT(*) AS qtd
# FROM SPACEXTABLE
# GROUP BY Customer
# ORDER BY qtd DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('NASA (CRS)', 20),
#  ('SpaceX', 13),
#  ('Iridium Communications', 7),
#  ('SES', 5),
#  ('Thaicom', 2),
#  ('Telesat', 2),
#  ('SpaceX, Planet Labs', 2),
#  ('SKY Perfect JSAT Group', 2),
#  ('Orbcomm', 2),
#  ('AsiaSat', 2),
#  ('ABS Eutelsat', 2),
#  ('USSF', 1),
#  ('USAF', 1),
#  ('U.S. Space Force', 1),
#  ('U.S. Air Force NASA NOAA', 1),
#  ('U.S. Air Force', 1),
#  ('Turkmenistan National Space Agency', 1),
#  ('Thales-Alenia/BTRC', 1),
#  ('Telkom Indonesia', 1),
#  ('Spaceflight Industries', 1),
#  ('Spacecom', 1),
#  ('SpaceX, Spaceflight Industries (BlackSky), Planet Labs', 1),
#  ('SpaceX, Planet Labs, PlanetIQ', 1),
#  ('Sky Perfect JSAT, Kacific 1', 1),
#  ('SES EchoStar', 1),
#  ('Republic of Korea Army, Spaceflight Industries (BlackSky)', 1),
#  ('PSN, SpaceIL / IAI', 1),
#  ('Northrop Grumman', 1),
#  ('NSPO', 1),
#  ('NRO', 1),
#  ('NASA / NOAA / ESA / EUMETSAT', 1),
#  ('NASA (LSP) NOAA CNES', 1),
#  ('NASA (LSP)', 1),
# ...

# %% [markdown]
# ### Task 4
#
#
#
# ##### Display average and max payload mass carried by booster version F9 v1.1

# %%
# %%sql
# SELECT AVG(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Booster_Version LIKE 'F9 v1.1%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2534.6666666666665,)]

# %%
# %%sql
# SELECT AVG(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Booster_Version LIKE 'F9 v1.2%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(None,)]

# %%
# %%sql
# SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Booster_Version LIKE 'F9 v1.1%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(4707,)]

# %% [markdown]
# ##### Display average and max payload mass carried by booster version F9 B5 B

# %%
# %%sql
# SELECT AVG(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Booster_Version LIKE 'F9 B5 B%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(10474.354838709678,)]

# %%
# %%sql
# SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTABLE WHERE Booster_Version LIKE 'F9 B5 B%';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(15600,)]

# %%
# %%sql
# SELECT Booster_Version, MAX(PAYLOAD_MASS__KG_) FROM SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600)]

# %%
# %%sql
# SELECT Booster_Version,PAYLOAD_MASS__KG_ FROM SPACEXTABLE
# ORDER BY PAYLOAD_MASS__KG_ DESC
# LIMIT 9;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', 15600),
#  ('F9 B5 B1049.4', 15600),
#  ('F9 B5 B1051.3', 15600),
#  ('F9 B5 B1056.4', 15600),
#  ('F9 B5 B1048.5', 15600),
#  ('F9 B5 B1051.4', 15600),
#  ('F9 B5 B1049.5', 15600),
#  ('F9 B5 B1060.2 ', 15600),
#  ('F9 B5 B1058.3 ', 15600)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome was acheived.

# %%
# %%sql
# SELECT MIN(Date) FROM SPACEXTABLE WHERE Mission_Outcome = 'Success';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2010-06-04',)]

# %%
# %%sql
# SELECT MIN(Date) FROM SPACEXTABLE WHERE Landing_Outcome = 'Success (ground pad)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-12-22',)]

# %%
# %%sql
# SELECT MIN(Date) FROM SPACEXTABLE WHERE Landing_Outcome = 'Success (drone ship)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2016-04-08',)]

# %%
# %%sql
# SELECT MIN(Date) FROM SPACEXTABLE WHERE Landing_Outcome = 'Success';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2018-07-22',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %%sql
# SELECT Booster_version FROM SPACEXTABLE
#     WHERE (Landing_Outcome = 'Success (drone ship)') AND
#         (PAYLOAD_MASS__KG_ > 4000 AND PAYLOAD_MASS__KG_ < 6000);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ##### List the name, payload and date of the boosters which have success in drone ship

# %%
# %%sql
# SELECT Booster_version, PAYLOAD_MASS__KG_, Date FROM SPACEXTABLE
#     WHERE (Landing_Outcome = 'Success (drone ship)') ;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1021.1', 3136, '2016-04-08'),
#  ('F9 FT B1022', 4696, '2016-05-06'),
#  ('F9 FT B1023.1', 3100, '2016-05-27'),
#  ('F9 FT B1026', 4600, '2016-08-14'),
#  ('F9 FT B1029.1', 9600, '2017-01-14'),
#  ('F9 FT  B1021.2', 5300, '2017-03-30'),
#  ('F9 FT  B1029.2', 3669, '2017-06-23'),
#  ('F9 FT B1036.1', 9600, '2017-06-25'),
#  ('F9 FT B1038.1', 475, '2017-08-24'),
#  ('F9 B4 B1041.1', 9600, '2017-10-09'),
#  ('F9 FT  B1031.2', 5200, '2017-10-11'),
#  ('F9 B4 B1042.1', 3500, '2017-10-30'),
#  ('F9 B4 B1045.1', 362, '2018-04-18'),
#  ('F9 B5  B1046.1', 3600, '2018-05-11')]

# %% [markdown]
# ##### List the names of the boosters which have success in ground pad and have payload mass greater than 4000 but less than 6000

# %%
# %%sql
# SELECT Booster_version FROM SPACEXTABLE
#     WHERE (Landing_Outcome = 'Success (ground pad)') AND
#         (PAYLOAD_MASS__KG_ > 4000 AND PAYLOAD_MASS__KG_ < 6000);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1032.1',), ('F9 B4 B1040.1',), ('F9 B4 B1043.1',)]

# %% [markdown]
# ##### List the names of the boosters which have success in ground pad

# %%
# %%sql
# SELECT Booster_version, PAYLOAD_MASS__KG_, Date FROM SPACEXTABLE
#     WHERE (Landing_Outcome = 'Success (ground pad)')
#     ORDER BY Date;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT B1019', 2034, '2015-12-22'),
#  ('F9 FT B1025.1', 2257, '2016-07-18'),
#  ('F9 FT B1031.1', 2490, '2017-02-19'),
#  ('F9 FT B1032.1', 5300, '2017-05-01'),
#  ('F9 FT B1035.1', 2708, '2017-06-03'),
#  ('F9 B4 B1039.1', 3310, '2017-08-14'),
#  ('F9 B4 B1040.1', 4990, '2017-09-07'),
#  ('F9 FT  B1035.2', 2205, '2017-12-15'),
#  ('F9 B4 B1043.1', 5000, '2018-01-08')]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %%sql
# SELECT Mission_outcome, COUNT(*) AS Count FROM SPACEXTABLE
#     GROUP BY Mission_outcome
#     ORDER BY COUNT(*) DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success', 98),
#  ('Success (payload status unclear)', 1),
#  ('Success ', 1),
#  ('Failure (in flight)', 1)]

# %% [markdown]
# ##### List the total number of successful and failure Landings Outcomes

# %%
# %%sql
# SELECT Landing_Outcome, COUNT(*) AS Count FROM SPACEXTABLE
#     GROUP BY Landing_Outcome
#     ORDER BY COUNT(*) DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success', 38),
#  ('No attempt', 21),
#  ('Success (drone ship)', 14),
#  ('Success (ground pad)', 9),
#  ('Failure (drone ship)', 5),
#  ('Controlled (ocean)', 5),
#  ('Failure', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1),
#  ('No attempt ', 1)]

# %%
# %%sql
# SELECT Landing_Outcome, COUNT(*) AS Count FROM SPACEXTABLE
#     GROUP BY Landing_Outcome
#     ORDER BY COUNT(*) DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success', 38),
#  ('No attempt', 21),
#  ('Success (drone ship)', 14),
#  ('Success (ground pad)', 9),
#  ('Failure (drone ship)', 5),
#  ('Controlled (ocean)', 5),
#  ('Failure', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1),
#  ('No attempt ', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List all the booster_versions that have carried the maximum payload mass, using a subquery with a suitable aggregate function.

# %% [markdown]
# ##### List all the booster_versions that have carried the maximum payload mass

# %%
# %%sql
# SELECT Booster_version, date, Mission_Outcome, Landing_Outcome FROM SPACEXTABLE
#     WHERE PAYLOAD_MASS__KG_ = (SELECT MAX(PAYLOAD_MASS__KG_) FROM SPACEXTBL);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5 B1048.4', '2019-11-11', 'Success', 'Success'),
#  ('F9 B5 B1049.4', '2020-01-07', 'Success', 'Success'),
#  ('F9 B5 B1051.3', '2020-01-29', 'Success', 'Success'),
#  ('F9 B5 B1056.4', '2020-02-17', 'Success', 'Failure'),
#  ('F9 B5 B1048.5', '2020-03-18', 'Success', 'Failure'),
#  ('F9 B5 B1051.4', '2020-04-22', 'Success', 'Success'),
#  ('F9 B5 B1049.5', '2020-06-04', 'Success', 'Success'),
#  ('F9 B5 B1060.2 ', '2020-09-03', 'Success', 'Success'),
#  ('F9 B5 B1058.3 ', '2020-10-06', 'Success', 'Success'),
#  ('F9 B5 B1051.6', '2020-10-18', 'Success', 'Success'),
#  ('F9 B5 B1060.3', '2020-10-24', 'Success', 'Success'),
#  ('F9 B5 B1049.7 ', '2020-11-25', 'Success', 'Success')]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# %%sql
# SELECT Date, Landing_Outcome, Booster_Version, Launch_Site FROM SPACEXTABLE
#     WHERE substr(Date, 1, 4) = '2015' AND Landing_outcome = 'Failure (drone ship)';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('2015-01-10', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('2015-04-14', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %% [markdown]
# #### List the records which will display the month names, failure landing_outcomes in drone ship, booster versions, launch_site for the months in year 2015.

# %%
# %%sql
# SELECT
#     CASE substr(Date, 6, 2)
#         WHEN '01' THEN 'January'
#         WHEN '02' THEN 'February'
#         WHEN '03' THEN 'March'
#         WHEN '04' THEN 'April'
#         WHEN '05' THEN 'May'
#         WHEN '06' THEN 'June'
#         WHEN '07' THEN 'July'
#         WHEN '08' THEN 'August'
#         WHEN '09' THEN 'September'
#         WHEN '10' THEN 'October'
#         WHEN '11' THEN 'November'
#         WHEN '12' THEN 'December'
#     END AS month_name,
#     Booster_Version,
#     Launch_Site,
#     Mission_Outcome
#     Landing_Outcome
# FROM
#     SPACEXTABLE
# WHERE
#     substr(Date, 1, 4) = '2015'
#     AND Landing_Outcome = 'Failure (drone ship)'
# ORDER BY
#     substr(Date, 6, 2);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('January', 'F9 v1.1 B1012', 'CCAFS LC-40', 'Success', 'Failure (drone ship)'),
#  ('April', 'F9 v1.1 B1015', 'CCAFS LC-40', 'Success', 'Failure (drone ship)')]

# %% [markdown]
# #### List the records which will display the month names, all failure landing_outcomes,booster versions, launch_site for the months in year 2015.

# %%
# %%sql
# SELECT
#     CASE substr(Date, 6, 2)
#         WHEN '01' THEN 'January'
#         WHEN '02' THEN 'February'
#         WHEN '03' THEN 'March'
#         WHEN '04' THEN 'April'
#         WHEN '05' THEN 'May'
#         WHEN '06' THEN 'June'
#         WHEN '07' THEN 'July'
#         WHEN '08' THEN 'August'
#         WHEN '09' THEN 'September'
#         WHEN '10' THEN 'October'
#         WHEN '11' THEN 'November'
#         WHEN '12' THEN 'December'
#     END AS month_name,
#     Booster_Version,
#     Launch_Site,
#     PAYLOAD_MASS__KG_,
#     Mission_Outcome,
#     Landing_Outcome
# FROM
#     SPACEXTABLE
#     WHERE  "Date" BETWEEN '2015-01-01' AND '2015-12-31'
# ORDER BY
#     substr(Date, 6, 2);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('January', 'F9 v1.1 B1012', 'CCAFS LC-40', 2395, 'Success', 'Failure (drone ship)'),
#  ('February', 'F9 v1.1 B1013', 'CCAFS LC-40', 570, 'Success', 'Controlled (ocean)'),
#  ('March', 'F9 v1.1 B1014', 'CCAFS LC-40', 4159, 'Success', 'No attempt'),
#  ('April', 'F9 v1.1 B1015', 'CCAFS LC-40', 1898, 'Success', 'Failure (drone ship)'),
#  ('April', 'F9 v1.1 B1016', 'CCAFS LC-40', 4707, 'Success', 'No attempt'),
#  ('June', 'F9 v1.1 B1018', 'CCAFS LC-40', 1952, 'Failure (in flight)', 'Precluded (drone ship)'),
#  ('December', 'F9 FT B1019', 'CCAFS LC-40', 2034, 'Success', 'Success (ground pad)')]

# %% [markdown]
# ### Task 10

# %% [markdown]
# ##### Rank the count of Mission Outcomes between the date 2010-06-04 and 2017-03-20

# %%
# %%sql
# SELECT "Mission_Outcome", COUNT("Mission_Outcome") AS "Total_Count" FROM SPACEXTABLE
#     WHERE  "Date" BETWEEN '2010-06-04' AND '2017-03-20'
#     GROUP BY "Mission_Outcome"
#     ORDER BY "Total_Count" DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success', 30), ('Failure (in flight)', 1)]

# %% [markdown]
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20

# %%
# %%sql
# SELECT "Landing_Outcome", COUNT("Landing_Outcome") AS "Total_Count" FROM SPACEXTABLE
#     WHERE  "Date" BETWEEN '2010-06-04' AND '2017-03-20'
#     GROUP BY "Landing_Outcome"
#     ORDER BY "Total_Count" DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('No attempt', 10),
#  ('Success (drone ship)', 5),
#  ('Failure (drone ship)', 5),
#  ('Success (ground pad)', 3),
#  ('Controlled (ocean)', 3),
#  ('Uncontrolled (ocean)', 2),
#  ('Failure (parachute)', 2),
#  ('Precluded (drone ship)', 1)]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# <!--
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2024-07-10 | 1.1 |Anita Verma | Changed Version|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |
# -->

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
